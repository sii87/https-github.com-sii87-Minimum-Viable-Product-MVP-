# %%
#Frist, we need to import the libraries that we will use in this notebook.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob 
import seaborn as sns
# %matplotlib inline

# %%
#Here I combined the files 
f2018 = [file for file in glob.glob('f2018/*.txt')]
f2018_all = pd.concat([pd.read_csv(file) for file in f2018])
f2018_all.to_csv('f2018.csv', index=False)

f2019 = [file for file in glob.glob('f2019/*.txt')]
f2019_all = pd.concat([pd.read_csv(file) for file in f2019])
f2019_all.to_csv('f2019.csv', index=False)

# %%
df_2018 = pd.read_csv('f2018.csv')
df_2019 = pd.read_csv('f2019.csv')

# %%
#Part 1 i will view data by{info() , tail() , head() , columns() , value() , dtype() For the month of February in 2018 and 2019}
df_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 794138 entries, 0 to 794137
# Data columns (total 11 columns):
#  #   Column                                                                Non-Null Count   Dtype
# ---  ------                                                                --------------   -----
#  0   C/A                                                                   794138 non-null  object
#  1   UNIT                                                                  794138 non-null  object
#  2   SCP                                                                   794138 non-null  object
#  3   STATION                                                               794138 non-null  object
#  4   LINENAME                                                              794138 non-null  object
#  5   DIVISION                                                              794138 non-null  object
# ...

# %%
df_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 814439 entries, 0 to 814438
# Data columns (total 11 columns):
#  #   Column                                                                Non-Null Count   Dtype
# ---  ------                                                                --------------   -----
#  0   C/A                                                                   814439 non-null  object
#  1   UNIT                                                                  814439 non-null  object
#  2   SCP                                                                   814439 non-null  object
#  3   STATION                                                               814439 non-null  object
#  4   LINENAME                                                              814439 non-null  object
#  5   DIVISION                                                              814439 non-null  object
# ...

# %%
df_2018.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/27/2018  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/27/2018  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/27/2018  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/27/2018  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/27/2018  19:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6495412
# 1  REGULAR  6495425
# 2  REGULAR  6495481
# 3  REGULAR  6495659
# 4  REGULAR  6495932
#
#    EXITS
# 0                                            2199512
# 1                                            2199519
# 2                                            2199588
# 3                                            2199639
# 4                                            2199697

# %%
df_2019.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/26/2019  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/26/2019  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/26/2019  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/26/2019  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/26/2019  19:00:00
#
#          DESC  ENTRIES  \
# 0     REGULAR  6922652
# 1     REGULAR  6922669
# 2     REGULAR  6922747
# 3  RECOVR AUD  6922932
# 4     REGULAR  6923237
#
#    EXITS
# 0                                            2347673
# 1                                            2347688
# 2                                            2347773
# 3                                            2347849
# 4                                            2347911

# %%
df_2018.shape
# Out:
# (794138, 11)

# %%
df_2018.tail()
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 794133  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
# 794134  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
# 794135  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
# 794136  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
# 794137  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
#
#             TIME     DESC  ENTRIES  \
# 794133  04:00:00  REGULAR  2498489
# 794134  08:00:00  REGULAR  2498596
# 794135  12:00:00  REGULAR  2499078
# 794136  16:00:00  REGULAR  2499316
# 794137  20:00:00  REGULAR  2499467
#
#         EXITS
# 794133                                              28036
# 794134                                              28039
# 794135                                              28040
# 794136                                              28041
# ...

# %%
df_2019.tail()
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 814434  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
# 814435  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
# 814436  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
# 814437  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
# 814438  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
#
#             TIME     DESC  ENTRIES  \
# 814434  04:00:00  REGULAR     5554
# 814435  08:00:00  REGULAR     5554
# 814436  12:00:00  REGULAR     5554
# 814437  16:00:00  REGULAR     5554
# 814438  20:00:00  REGULAR     5554
#
#         EXITS
# 814434                                                369
# 814435                                                369
# 814436                                                369
# 814437                                                369
# ...

# %%
df_2019.shape
# Out:
# (814439, 11)

# %%
df_2018.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
#Now I will rename the C/A column to C_A.
df_2018.rename(columns = {'C/A': 'C_A'}, inplace = True)
df_2018
# Out:
#           C_A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/27/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/27/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/27/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/27/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/27/2018
# ...       ...   ...       ...            ...      ...      ...         ...
# 794133  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
# 794134  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
# 794135  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
# 794136  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
# 794137  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
#
#             TIME     DESC  ENTRIES  \
# ...

# %%
df_2019.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
df_2019.rename(columns = {'C/A': 'C_A'}, inplace = True)
df_2019
# Out:
#           C_A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/26/2019
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/26/2019
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/26/2019
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/26/2019
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/26/2019
# ...       ...   ...       ...            ...      ...      ...         ...
# 814434  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
# 814435  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
# 814436  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
# 814437  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
# 814438  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
#
#             TIME        DESC  ENTRIES  \
# ...

# %%
df_2018.values
# Out:
# array([['A002', 'R051', '02-00-00', ..., 'REGULAR', 6495412, 2199512],
#        ['A002', 'R051', '02-00-00', ..., 'REGULAR', 6495425, 2199519],
#        ['A002', 'R051', '02-00-00', ..., 'REGULAR', 6495481, 2199588],
#        ...,
#        ['TRAM2', 'R469', '00-03-01', ..., 'REGULAR', 2499078, 28040],
#        ['TRAM2', 'R469', '00-03-01', ..., 'REGULAR', 2499316, 28041],
#        ['TRAM2', 'R469', '00-03-01', ..., 'REGULAR', 2499467, 28042]],
#       dtype=object)

# %%
df_2018.values
# Out:
# array([['A002', 'R051', '02-00-00', ..., 'REGULAR', 6495412, 2199512],
#        ['A002', 'R051', '02-00-00', ..., 'REGULAR', 6495425, 2199519],
#        ['A002', 'R051', '02-00-00', ..., 'REGULAR', 6495481, 2199588],
#        ...,
#        ['TRAM2', 'R469', '00-03-01', ..., 'REGULAR', 2499078, 28040],
#        ['TRAM2', 'R469', '00-03-01', ..., 'REGULAR', 2499316, 28041],
#        ['TRAM2', 'R469', '00-03-01', ..., 'REGULAR', 2499467, 28042]],
#       dtype=object)

# %%
df_2018.dtypes
# Out:
# C/A                                                                     object
# UNIT                                                                    object
# SCP                                                                     object
# STATION                                                                 object
# LINENAME                                                                object
# DIVISION                                                                object
# DATE                                                                    object
# TIME                                                                    object
# DESC                                                                    object
# ENTRIES                                                                  int64
# EXITS                                                                    int64
# dtype: object

# %%
df_2019.dtypes
# Out:
# C/A                                                                     object
# UNIT                                                                    object
# SCP                                                                     object
# STATION                                                                 object
# LINENAME                                                                object
# DIVISION                                                                object
# DATE                                                                    object
# TIME                                                                    object
# DESC                                                                    object
# ENTRIES                                                                  int64
# EXITS                                                                    int64
# dtype: object

# %%
#Now I will describe the data 
df_2018.describe()
# Out:
#             ENTRIES  \
# count  7.941380e+05
# mean   3.967046e+07
# std    2.072002e+08
# min    0.000000e+00
# 25%    4.984438e+05
# 50%    2.642564e+06
# 75%    6.930886e+06
# max    2.130113e+09
#
#        EXITS
# count                                       7.941380e+05
# mean                                        3.212197e+07
# std                                         1.886277e+08
# min                                         0.000000e+00
# 25%                                         2.519320e+05
# 50%                                         1.478830e+06
# 75%                                         4.837974e+06
# max                                         2.096904e+09

# %%
df_2018.describe()
# Out:
#             ENTRIES  \
# count  7.941380e+05
# mean   3.967046e+07
# std    2.072002e+08
# min    0.000000e+00
# 25%    4.984438e+05
# 50%    2.642564e+06
# 75%    6.930886e+06
# max    2.130113e+09
#
#        EXITS
# count                                       7.941380e+05
# mean                                        3.212197e+07
# std                                         1.886277e+08
# min                                         0.000000e+00
# 25%                                         2.519320e+05
# 50%                                         1.478830e+06
# 75%                                         4.837974e+06
# max                                         2.096904e+09

# %%
#To check if there are data of months other than February
df_2018.DATE.value_counts().sort_index()
# Out:
# 01/27/2018    28140
# 01/28/2018    28279
# 01/29/2018    28275
# 01/30/2018    28499
# 01/31/2018    29112
# 02/01/2018    28798
# 02/02/2018    28285
# 02/03/2018    28141
# 02/04/2018    28341
# 02/05/2018    28131
# 02/06/2018    28135
# 02/07/2018    28388
# 02/08/2018    28215
# 02/09/2018    28124
# 02/10/2018    28055
# 02/11/2018    28057
# 02/12/2018    28391
# 02/13/2018    29124
# 02/14/2018    29144
# 02/15/2018    28179
# 02/16/2018    28415
# 02/17/2018    28074
# 02/18/2018    28085
# 02/19/2018    28027
# 02/20/2018    29166
# 02/21/2018    28250
# 02/22/2018    28030
# 02/23/2018    28278
# Name: DATE, dtype: int64

# %%
#To check if there are data of months other than February
df_2019.DATE.value_counts().sort_index()
# Out:
# 01/26/2019    28757
# 01/27/2019    28792
# 01/28/2019    29049
# 01/29/2019    29103
# 01/30/2019    29285
# 01/31/2019    28755
# 02/01/2019    29171
# 02/02/2019    28597
# 02/03/2019    28676
# 02/04/2019    28884
# 02/05/2019    29681
# 02/06/2019    28789
# 02/07/2019    29411
# 02/08/2019    28697
# 02/09/2019    28794
# 02/10/2019    28765
# 02/11/2019    29291
# 02/12/2019    29021
# 02/13/2019    30079
# 02/14/2019    29655
# 02/15/2019    29132
# 02/16/2019    28765
# 02/17/2019    28978
# 02/18/2019    29161
# 02/19/2019    29480
# 02/20/2019    29280
# 02/21/2019    29208
# 02/22/2019    29183
# Name: DATE, dtype: int64

# %%
#I Created a column of type datetime
df_2018["DATE_TIME"] = pd.to_datetime(df_2018.DATE + " " + df_2018.TIME, format="%m/%d/%Y %H:%M:%S")
df_2018
# Out:
#           C_A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/27/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/27/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/27/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/27/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/27/2018
# ...       ...   ...       ...            ...      ...      ...         ...
# 794133  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
# 794134  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
# 794135  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
# 794136  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
# 794137  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
#
#             TIME     DESC  ENTRIES  \
# ...

# %%
df_2019["DATE_TIME"] = pd.to_datetime(df_2019.DATE + " " + df_2019.TIME, format="%m/%d/%Y %H:%M:%S")
df_2019
# Out:
#           C_A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/26/2019
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/26/2019
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/26/2019
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/26/2019
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/26/2019
# ...       ...   ...       ...            ...      ...      ...         ...
# 814434  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
# 814435  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
# 814436  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
# 814437  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
# 814438  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
#
#             TIME        DESC  ENTRIES  \
# ...

# %%
#I will delete the time column
df_2019.drop('TIME' , axis = 1 , inplace = True )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-bd697f2fd331> in <module>
# ----> 1 df_2019.drop('TIME' , axis = 1 , inplace = True )
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df_2018.drop('TIME' , axis = 1 , inplace = True )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-0e670bb79960> in <module>
# ----> 1 df_2018.drop('TIME' , axis = 1 , inplace = True )
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
#Deleted
df_2018
# Out:
#           C_A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/27/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/27/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/27/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/27/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/27/2018
# ...       ...   ...       ...            ...      ...      ...         ...
# 794133  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
# 794134  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
# 794135  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
# 794136  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
# 794137  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
#
#            DESC  ENTRIES  \
# 0       REGULAR  6495412
# ...

# %%
df_2019
# Out:
#           C_A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/26/2019
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/26/2019
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/26/2019
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/26/2019
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/26/2019
# ...       ...   ...       ...            ...      ...      ...         ...
# 814434  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
# 814435  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
# 814436  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
# 814437  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
# 814438  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
#
#               DESC  ENTRIES  \
# 0          REGULAR  6922652
# ...

# %%
df_2018[df_2018.isna()].count()
# Out:
# C_A                                                                     0
# UNIT                                                                    0
# SCP                                                                     0
# STATION                                                                 0
# LINENAME                                                                0
# DIVISION                                                                0
# DATE                                                                    0
# DESC                                                                    0
# ENTRIES                                                                 0
# EXITS                                                                   0
# DATE_TIME                                                               0
# dtype: int64

# %%
df_2019[df_2019.isna()].count()
# Out:
# C_A                                                                     0
# UNIT                                                                    0
# SCP                                                                     0
# STATION                                                                 0
# LINENAME                                                                0
# DIVISION                                                                0
# DATE                                                                    0
# DESC                                                                    0
# ENTRIES                                                                 0
# EXITS                                                                   0
# DATE_TIME                                                               0
# dtype: int64

# %%
#There is no NaN in the data frames.

# %%
df_2018.drop_duplicates(subset=["C_A", "UNIT", "SCP", "STATION", "DATE_TIME"], inplace=True)
df_2018
# Out:
#           C_A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/27/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/27/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/27/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/27/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/27/2018
# ...       ...   ...       ...            ...      ...      ...         ...
# 794133  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
# 794134  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
# 794135  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
# 794136  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
# 794137  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  02/23/2018
#
#            DESC  ENTRIES  \
# 0       REGULAR  6495412
# ...

# %%
df_2019.drop_duplicates(subset=["C_A", "UNIT", "SCP", "STATION", "DATE_TIME"], inplace=True)
df_2019
# Out:
#           C_A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/26/2019
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/26/2019
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/26/2019
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/26/2019
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  01/26/2019
# ...       ...   ...       ...            ...      ...      ...         ...
# 814434  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
# 814435  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
# 814436  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
# 814437  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
# 814438  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  02/22/2019
#
#               DESC  ENTRIES  \
# 0          REGULAR  6922652
# ...

# %%
SAMPLESTATION=df_2018[df_2018['STATION']=='59 ST']
sns.boxplot(SAMPLESTATION['ENTRIES'])
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ENTRIES'>

# %%
SAMPLESTATION=df_2019[df_2019['STATION']=='59 ST']
sns.boxplot(SAMPLESTATION['ENTRIES'])
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ENTRIES'>

# %%
#PLOTTING THE DISTRIBUTION OF ENTRIES WITH THE OUTLIERS
plt.figure(figsize=(13,10))
plt.title("Distribution of entries", fontsize=20);
plt.xlabel("Entries", fontsize=15)
plt.ylabel("Density", fontsize=15)
sns.distplot(df_2018.ENTRIES)
plt.savefig('graph000.png')

plt.figure()

plt.figure(figsize=(13,10))
plt.title("cumulative probability distribution of entries", fontsize=20);
plt.xlabel("Entries", fontsize=15)
plt.ylabel("Density", fontsize=15)
sns.distplot(df_2018.ENTRIES,hist_kws={"cumulative":True},kde_kws={"cumulative":True})
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'cumulative probability distribution of entries'}, xlabel='ENTRIES', ylabel='Density'>

# %%
#PLOTTING THE DISTRIBUTION OF ENTRIES WITH THE OUTLIERS
plt.figure(figsize=(13,10))
plt.title("Distribution of entries", fontsize=20);
plt.xlabel("Entries", fontsize=15)
plt.ylabel("Density", fontsize=15)
sns.distplot(df_2019.ENTRIES)
plt.savefig('graph000.png')

plt.figure()

plt.figure(figsize=(13,10))
plt.title("cumulative probability distribution of entries", fontsize=20);
plt.xlabel("Entries", fontsize=15)
plt.ylabel("Density", fontsize=15)
sns.distplot(df_2019.ENTRIES,hist_kws={"cumulative":True},kde_kws={"cumulative":True})
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'cumulative probability distribution of entries'}, xlabel='ENTRIES', ylabel='Density'>
